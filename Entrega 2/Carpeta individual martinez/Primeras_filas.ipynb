# %% [markdown]
# # **Leer base de datos y limpieza de esta**

# %%
import pandas as pd

df = pd.read_csv('/content/storms.csv')

# %%
df
# Out:
#        Unnamed: 0   name  year  month  day  hour   lat  long  \
# 0               1    Amy  1975      6   27     0  27.5 -79.0
# 1               2    Amy  1975      6   27     6  28.5 -79.0
# 2               3    Amy  1975      6   27    12  29.5 -79.0
# 3               4    Amy  1975      6   27    18  30.5 -79.0
# 4               5    Amy  1975      6   28     0  31.5 -78.8
# ...           ...    ...   ...    ...  ...   ...   ...   ...
# 19061       19062  Wanda  2021     11    7     0  37.4 -37.4
# 19062       19063  Wanda  2021     11    7     6  38.1 -36.4
# 19063       19064  Wanda  2021     11    7    12  39.2 -34.9
# 19064       19065  Wanda  2021     11    7    18  40.9 -32.8
# 19065       19066  Wanda  2021     11    8     0  43.2 -29.7
#
#                     status  category  wind  pressure  \
# 0      tropical depression       NaN    25      1013
# 1      tropical depression       NaN    25      1013
# 2      tropical depression       NaN    25      1013
# ...

# %%
len(df)
# Out:
# 19066

# %%
# Eliminar los NA de la columna 'Nombre'
df_limpio = df.dropna(subset=['tropicalstorm_force_diameter'])

# Mostrar el DataFrame limpio
print("\nDataFrame después de eliminar los NA en 'tropicalstorm_force_diameter	':")
display(df_limpio)
# Out:
# DataFrame después de eliminar los NA en 'tropicalstorm_force_diameter	':
#        Unnamed: 0   name  year  month  day  hour   lat  long  \
# 9432         9433   Alex  2004      7   31    18  30.3 -78.3
# 9433         9434   Alex  2004      8    1     0  31.0 -78.8
# 9434         9435   Alex  2004      8    1     6  31.5 -79.0
# 9435         9436   Alex  2004      8    1    12  31.6 -79.1
# 9436         9437   Alex  2004      8    1    18  31.6 -79.2
# ...           ...    ...   ...    ...  ...   ...   ...   ...
# 19061       19062  Wanda  2021     11    7     0  37.4 -37.4
# 19062       19063  Wanda  2021     11    7     6  38.1 -36.4
# 19063       19064  Wanda  2021     11    7    12  39.2 -34.9
# 19064       19065  Wanda  2021     11    7    18  40.9 -32.8
# 19065       19066  Wanda  2021     11    8     0  43.2 -29.7
#
#                     status  category  wind  pressure  \
# 9432   tropical depression       NaN    25      1010
# ...

# %%
len(df_limpio)
# Out:
# 9554

# %%
df_limpio.to_excel('base de datos limpia.xlsx', index=False)

# %%
df_final = pd.read_csv('/content/NOAA Atlantic Hurricane dataset (LIMPIA).csv', sep=';')

# %% [markdown]
# # **primeras filas de la base de datos**

# %%
df_final.head()
# Out:
#    Unnamed: 0  name  year  month  day  hour   lat   long               status  \
# 0        9433  Alex  2004      7   31    18  30,3  -78,3  tropical depression
# 1        9434  Alex  2004      8    1     0    31  -78,8  tropical depression
# 2        9435  Alex  2004      8    1     6  31,5    -79  tropical depression
# 3        9436  Alex  2004      8    1    12  31,6  -79,1  tropical depression
# 4        9437  Alex  2004      8    1    18  31,6  -79,2       tropical storm
#
#    category  wind  pressure  tropicalstorm_force_diameter  \
# 0       NaN    25      1010                             0
# 1       NaN    25      1009                             0
# 2       NaN    25      1009                             0
# 3       NaN    30      1009                             0
# 4       NaN    35      1009                            50
#
#    hurricane_force_diameter
# 0                         0
# 1                         0
# 2                         0
# 3                         0
# ...
